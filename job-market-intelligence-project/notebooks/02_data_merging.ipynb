# %%
import pandas as pd

# %%
jobs = pd.read_csv("C:/Users/riyak/OneDrive/Documents/job-market-intelligence-project/data/raw/adzuna_global_job_listings_2025.csv")
salary = pd.read_csv("C:/Users/riyak/OneDrive/Documents/job-market-intelligence-project/data/raw/DataScience_salaries_2024.csv")

# %%
jobs = jobs.rename(columns={'title':'job_title'})

# %%
jobs['job_title'] = jobs['job_title'].str.lower()
salary['job_title'] = salary['job_title'].str.lower()

# %%
merged_df = pd.merge(jobs, salary, on='job_title', how='inner')

# %%
merged_df.shape
# Out:
# (35627, 28)

# %%
merged_df.head()
# Out:
#        job_id                    job_title        company  \
# 0  4811316526  machine learning researcher  Quanta Search
# 1  4811316526  machine learning researcher  Quanta Search
# 2  4811316526  machine learning researcher  Quanta Search
# 3  4811316526  machine learning researcher  Quanta Search
# 4  4811316526  machine learning researcher  Quanta Search
#
#           location_display                        location_area  \
# 0  New York City, New York  ['US', 'New York', 'New York City']
# 1  New York City, New York  ['US', 'New York', 'New York City']
# 2  New York City, New York  ['US', 'New York', 'New York City']
# 3  New York City, New York  ['US', 'New York', 'New York City']
# 4  New York City, New York  ['US', 'New York', 'New York City']
#
#                                          description               created  \
# 0  Our client is a process driven investment mana...  2024-08-05T11:05:19Z
# 1  Our client is a process driven investment mana...  2024-08-05T11:05:19Z
# 2  Our client is a process driven investment mana...  2024-08-05T11:05:19Z
# 3  Our client is a process driven investment mana...  2024-08-05T11:05:19Z
# 4  Our client is a process driven investment mana...  2024-08-05T11:05:19Z
#
#   contract_time contract_type  salary_min  ...  work_year  experience_level  \
# 0           NaN           NaN   147795.31  ...       2024                SE
# 1           NaN           NaN   147795.31  ...       2023                MI
# 2           NaN           NaN   147795.31  ...       2023                SE
# 3           NaN           NaN   147795.31  ...       2024                MI
# 4           NaN           NaN   147795.31  ...       2023                MI
#
#   employment_type  salary salary_currency  salary_in_usd  employee_residence  \
# 0              FT  250800             USD         250800                  US
# 1              FT  224400             USD         224400                  US
# 2              FT  212000             USD         212000                  US
# 3              FT  210000             USD         210000                  US
# 4              FT  210000             USD         210000                  US
#
#   remote_ratio  company_location company_size
# 0            0                US            M
# 1            0                US            M
# 2            0                US            M
# 3            0                US            M
# 4            0                US            S
#
# [5 rows x 28 columns]

# %%
merged_df.to_csv("C:/Users/riyak/OneDrive/Documents/job-market-intelligence-project/data/processed/job_market_dataset.csv", index=False)

# %%
merged_df.shape
# Out:
# (35627, 28)
